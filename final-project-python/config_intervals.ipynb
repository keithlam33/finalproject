# %%
# 每個 interval 的 API 最大可抓天數（初始估值，建議實測後調整）
API_MAX_DAYS = {
    "1m": 7,
    "5m": 60,
    "15m": 60,
    "30m": 60,
    "1h": 365,
    "4h": 365,
    "D": 99999,
}

# 主表保留策略（主表保留 hot data 天數）
MAIN_TABLE_RETENTION_DAYS = {
    "1m": 7,
    "5m": 30,
    "15m": 60,
    "30m": 90,
    "1h": 180,
    "4h": 365,
    "D": 99999,
}

# archive 再保留天數（可選）
ARCHIVE_RETENTION_DAYS = {
    "1m": 365,
    "5m": 365 * 2,
    "15m": 365 * 3,
    "30m": 365 * 3,
    "1h": 365 * 5,
    "4h": 365 * 5,
    "D": 99999,
}
